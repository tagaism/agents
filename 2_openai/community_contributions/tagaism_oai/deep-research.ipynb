# %% [markdown]
# ## Deep Research

# %%
from agents import Agent, WebSearchTool, trace, Runner, gen_trace_id, function_tool
from agents.model_settings import ModelSettings
from pydantic import BaseModel, Field
from dotenv import load_dotenv
import asyncio
import sendgrid
import os
from sendgrid.helpers.mail import Mail, Email, To, Content
from typing import Dict
from IPython.display import display, Markdown

# %%
load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ## OpenAI Hosted Tools

# %%
INSTRUCTIONS = "You are a research assistant. Given a search term, you search the web for that term and \
produce a concise summary of the results. The summary must 2-3 paragraphs and less than 300 \
words. Capture the main points. Write succintly, no need to have complete sentences or good \
grammar. This will be consumed by someone synthesizing a report, so it's vital you capture the \
essence and ignore any fluff. Do not include any additional commentary other than the summary itself."

search_agent = Agent(
    name="Search agent",
    instructions=INSTRUCTIONS,
    tools=[WebSearchTool(search_context_size="low")],
    model="gpt-4o-mini",
    model_settings=ModelSettings(tool_choice="required"),
)

# %%
message="Latest AI agent framworks in 2026"

with trace("Search"):
    result = await Runner.run(search_agent, message)

display(Markdown(result.final_output))
# Out:
# As of May 2026, several AI agent frameworks have emerged, each catering to specific needs in the development of autonomous AI systems:
#
# - **OpenClaw**: Leading with over 280,000 GitHub stars, OpenClaw has become one of the most starred repositories in history. ([aimagicx.com](https://www.aimagicx.com/blog/best-open-source-ai-agent-frameworks-2026?utm_source=openai))
#
# - **AutoGen**: Previously a top choice for enterprise multi-agent systems, AutoGen is now in maintenance mode, with Microsoft redirecting developers to an early-access successor product. ([awesomeagents.ai](https://awesomeagents.ai/tools/best-ai-agent-frameworks-2026/?utm_source=openai))
#
# - **CrewAI**: With 49.8k stars, CrewAI is recognized for its intuitive role-playing paradigm and has achieved FedRAMP High compliance, supporting over 25 LLM providers out of the box. ([awesomeagents.ai](https://awesomeagents.ai/tools/best-ai-agent-frameworks-2026/?utm_source=openai))
#
# - **LangGraph**: Specializing in complex stateful workflows, LangGraph boasts 30.3k stars and is noted for its durable execution and weekly releases. ([awesomeagents.ai](https://awesomeagents.ai/tools/best-ai-agent-frameworks-2026/?utm_source=openai))
#
# - **Agno (formerly Phidata)**: Rebranded as Agno, this framework is designed for production multi-agent systems with a control plane, offering robust support for tool use, memory, and multi-agent patterns. ([awesomeagents.ai](https://awesomeagents.ai/tools/best-ai-agent-frameworks-2026/?utm_source=openai))
#
# - **PydanticAI**: Emphasizing type-safe structured agents, PydanticAI has gained traction for its growing community and production maturity. ([awesomeagents.ai](https://awesomeagents.ai/tools/best-ai-agent-frameworks-2026/?utm_source=openai))
#
# - **Semantic Kernel**: Backed by Microsoft, Semantic Kernel is tailored for enterprise and Azure integration, providing a comprehensive suite for building AI agents. ([awesomeagents.ai](https://awesomeagents.ai/tools/best-ai-agent-frameworks-2026/?utm_source=openai))
#
# - **LlamaIndex**: Specializing in document-heavy retrieval-augmented generation (RAG) workflows, LlamaIndex offers tools for efficient information retrieval and processing. ([awesomeagents.ai](https://awesomeagents.ai/tools/best-ai-agent-frameworks-2026/?utm_source=openai))
#
# These frameworks represent the forefront of AI agent development, each offering unique features to address diverse application requirements.
